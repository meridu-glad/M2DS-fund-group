# %%
def load_q_table():
    global Q_TABLE
    if Q_TABLE is None:
        if os.path.exists(Q_TABLE_PATH):
            Q_TABLE = np.load(Q_TABLE_PATH)
            print("Q-table loaded successfully.")
        else:
            # Create a blank Q-table instead of crashing
            # Taxi-v3 has 500 states and 6 actions
            print("Q-table not found. Creating a blank table for testing...")
            Q_TABLE = np.zeros([500, 6]) 
    return Q_TABLE
